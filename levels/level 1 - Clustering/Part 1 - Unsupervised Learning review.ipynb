# %% [markdown]
# ![image.png](attachment:cfebf040-b178-4a32-b32b-ad6599ae28e9.png)

# %% [markdown]
# ### Метрики для обучения с учителем не подходят для обучения без учителя!

# %% [markdown]
# ![image.png](attachment:9556a4bb-5b38-44db-9c9b-c38a3b28ae61.png)

# %% [markdown]
# ### Принадлежность к конкретному кластеру мы можем принимать как целевую переменную
