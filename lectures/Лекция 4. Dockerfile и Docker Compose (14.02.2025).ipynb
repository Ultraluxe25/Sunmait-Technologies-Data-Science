# %% [markdown]
# ### Dockerfile хранит в себе набор инструкций для сборки докер образа (Docker image)
# ![image.png](attachment:9ae6abca-d135-4655-b0d5-6dc6f66705f8.png)

# %% [markdown]
# ### Multi-stage builder позволяет засунуть контейнер в контейнер, чтобы уменьшить размер билда

# %% [markdown]
# ![image.png](attachment:6e4a20d7-24dc-45c0-8cc2-887f5647ea0c.png)
# ### Делаем merge request

# %% [markdown]
# ![image.png](attachment:cafd573f-dc8e-49cd-9551-2e0ba46ba2cc.png)
# ![image.png](attachment:de3669c3-e2fc-4a13-8d0a-79098d990676.png)

# %% [markdown]
# ![image.png](attachment:39d03bef-f19f-4c02-a260-0929086fdab5.png)
# ![image.png](attachment:2d6cbecb-644f-4291-925d-bfc4acd8c5b5.png)
