# %% [markdown]
# ![image.png](attachment:e6cde95c-41e0-4d18-8fc4-d9e0afbf57ec.png)

# %% [markdown]
# ### Открываем Add Dev Container Configuration Files... (Docker Desktop должен быть предварительно запущен!)

# %% [markdown]
# ![image.png](attachment:4d0611c4-12be-4ef3-9262-7167b18a1ee5.png)

# %% [markdown]
# ### Далее выбираем первый вариант: Add configuration to workspace

# %% [markdown]
# ![image.png](attachment:dfa77c0a-ce78-4db6-b8ed-144cb34caa48.png)

# %% [markdown]
# ![image.png](attachment:36668e94-c890-46f6-a7f2-e3d1c74949e4.png)
# ### Выбираем простой Python 3 и в нем версию 3.12 bookworm

# %% [markdown]
# ### Добавляем три библиотечки: PyTest, uv и ruff
# ![image.png](attachment:72f3427a-6b00-4840-ae00-0ec51abfc30b.png)
# ![image.png](attachment:a4d20ee8-2f2f-4346-80c3-328711a7e7b4.png)

# %% [markdown]
# ![image.png](attachment:3a70ec7c-e0ad-4766-8f54-e4fa83f3c133.png)
# ### Получаем вот такой файл

# %% [markdown]
# ![image.png](attachment:c3773d4e-98ed-4783-831c-75c61655e7d9.png)
# ### Теперь нажимаем Reopen in container

# %% [markdown]
# ![image.png](attachment:b183550e-4b2d-49a5-a434-67e3ddcd6315.png)
# ### Папка открывается внутри контейнера

# %% [markdown]
# ![image.png](attachment:1db9c403-16ad-4f66-89a8-27290faa763b.png)
# ### Появился image нашего проекта vsc-home-work-1

# %% [markdown]
# ![image.png](attachment:eb123d76-4953-4f1c-8739-a9dc9ff84e9d.png)
# ### Изучаем менеджер пакетов uv

# %% [markdown]
# ![image.png](attachment:bebc65a7-7d2b-478b-9914-44bb46106e67.png)
# ### Инициализируем новый проект в текущей директории и создается дефолтное наполнение проекта

# %% [markdown]
# ![image.png](attachment:8fe4f7ff-4295-4e5c-b23d-fbdb32b8e5ac.png)

# %% [markdown]
# ### Запускаем главный файл проекта командой `uv run hello.py`. После этого также создастся виртуальное окружение .venv
# ![image.png](attachment:ecdb80c0-c67e-4310-bef7-d69bb8a938dc.png)

# %% [markdown]
# ### Команда `uv add <библиотека>` позволяет установить любую библиотеку
# ![image.png](attachment:bba37a2a-48d0-460e-bd5f-459f4bf2e567.png)

# %% [markdown]
# ### `uv pip list` покажет список всех установленных либ
# ![image.png](attachment:d2df3f0c-db08-4b02-8fd5-5bb935a341b5.png)

# %% [markdown]
# ### Зависимости нашего проекта автоматически расширелись
# ![image.png](attachment:9a4e0907-c1f4-4ebe-84f1-0724a3e5981a.png)

# %% [markdown]
# ### Используем `ruff format` для форматирования кода
# ![image.png](attachment:fed6c8d4-bca8-45f8-a34b-5d22fafd470e.png)
# ![image.png](attachment:f5a00416-edff-4868-ba8d-713003563c3f.png)

# %% [markdown]
# ![image.png](attachment:02cc6473-43f5-4997-b97e-129ecd9f6152.png)

# %% [markdown]
# ### Команда `ruff check` обнаружила что у нас есть переменная, которая не используется. Всегда нужно удалять неиспользуемые переменные и импорты
# ![image.png](attachment:f4b08ee3-dda1-4dea-abc2-fb4474db6bcc.png)

# %% [markdown]
# ![image.png](attachment:2205350b-cda3-4917-9f39-932ac6886e22.png)

# %% [markdown]
# ### Чтобы VS Code не ругался на наши либы, выбираем наш интерпретатор
# ![image.png](attachment:00122697-5e5b-4e6c-ae9c-d4c5a10568c7.png)

# %% [markdown]
# ### Исправив ошибку в коде и пожелания ruff check-ера мы получаем готовый код
# ![image.png](attachment:13b7d4be-85ab-47ac-9eab-764cd6ee66bc.png)

# %% [markdown]
# ### Без библиотеки ipykernel не удастся запускать .ipynb код в проекте и проверять ruff на нем
# ![image.png](attachment:56ffe19b-a340-4c6b-b362-c0a892e2af56.png)

# %% [markdown]
# ### Команда `ruff check --fix` автоматически убрала matplotlib, который мы не использовали в коде
# ![image.png](attachment:577b37bb-cd64-4cb5-bbb6-04d7e57efa24.png)

# %% [markdown]
# ![image.png](attachment:4917da82-34bb-4a16-8ce9-904a7be9b6f9.png)

# %% [markdown]
# ### Код выше позволит развернуть такой же проект у себя вашему коллеге
